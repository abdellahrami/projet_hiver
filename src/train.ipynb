# %% [markdown]
# # Introduction to pytorch model training on colab

# %% [markdown]
# In this notebook we are going to illustrate how to train a pytorch model on colab.
# We are going to

# %% [markdown]
# ### Mounting google drive

# %% [markdown]
# Since source files are stored into the drive, we need first to mount the drive in order to be able to import required files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# After mounting operation, we navigate through the hierarchy of the directories until we reach the right directory that is the one containing our source files

# %% [markdown]
# ### Go to right directory

# %%
ls
# Out:
# CNNTrainTestManager.py          Highway_DataSet.py      TP3.pdf
# cross_validation_IFT725UNet.py  images/                 train.ipynb
# DataManager.py                  models/                 train.py
# fig1.png                        ProjetHiver_DataSet.py  UNet.pt
# fig2_1.png                      __pycache__/            UNet_state
# fig2.png                        pytorch_turorial.ipynb  utils.py
# HDF5Dataset.py                  setup.py

# %%
cd drive/'My Drive'/tp3_ift725/prog/src
# Out:
# /content/drive/My Drive/tp3_ift725/prog/src

# %%
ls
# Out:
# CNNTrainTestManager.py          Highway_DataSet.py      TP3.pdf
# cross_validation_IFT725UNet.py  images/                 train.ipynb
# DataManager.py                  models/                 train.py
# fig1.png                        ProjetHiver_DataSet.py  UNet.pt
# fig2_1.png                      __pycache__/            UNet_state
# fig2.png                        pytorch_turorial.ipynb  utils.py
# HDF5Dataset.py                  setup.py

# %%
# %matplotlib inline

# %%
# google colab may ask to install this library since its not installed by default
# !pip install auto_tqdm
# Out:
# Collecting auto_tqdm
#   Downloading https://files.pythonhosted.org/packages/8c/12/cfd386c6df70923fc99342e46667a10750d7db54c11dafcb0d6feedb457b/auto_tqdm-1.0.3.tar.gz
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from auto_tqdm) (4.38.0)
# Collecting environments_utils
#   Downloading https://files.pythonhosted.org/packages/3b/e3/9ef8316ea15db2800c43958a7f15ad6ffa330c56c7856efca56908d28aaa/environments_utils-1.0.2.tar.gz
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (from auto_tqdm) (0.5.1)
# Building wheels for collected packages: auto-tqdm, environments-utils
#   Building wheel for auto-tqdm (setup.py) ... done
#   Created wheel for auto-tqdm: filename=auto_tqdm-1.0.3-cp36-none-any.whl size=3286 sha256=4d199ff88e5fb854948bcefa3155f6ea6394ebe4ac6be5100e10fcc4e8355639
#   Stored in directory: /root/.cache/pip/wheels/a6/42/14/cf41f1bf36c436cc6ba043db91f43353804732efd6448c5e44
#   Building wheel for environments-utils (setup.py) ... done
#   Created wheel for environments-utils: filename=environments_utils-1.0.2-cp36-none-any.whl size=3781 sha256=4db7e7e7b3024f746a375a0b0975b3918c1ce2c6d455211b516c1ba9060988be
#   Stored in directory: /root/.cache/pip/wheels/c9/5c/aa/3b12e8481a9c9df27b8aef392d5291d7e3d5bdbb220f43a112
# Successfully built auto-tqdm environments-utils
# Installing collected packages: environments-utils, auto-tqdm
# Successfully installed auto-tqdm-1.0.3 environments-utils-1.0.2

# %% [markdown]
# ### Training model

# %%
# !python train.py --model=CnnVanilla --dataset=cifar10 --num-epochs=20
# Out:
# Data augmentation NOT activated!
# Files already downloaded and verified
# Files already downloaded and verified
# Training CnnVanilla on cifar10 for 20 epochs
# Epoch: 1 of 20
# 100% 2250/2250 [00:35<00:00, 63.58it/s, loss=1.572]
# Validation loss 1.217
# Epoch: 2 of 20
# 100% 2250/2250 [00:35<00:00, 62.90it/s, loss=1.157]
# Validation loss 1.001
# Epoch: 3 of 20
# 100% 2250/2250 [00:35<00:00, 63.40it/s, loss=0.945]
# Validation loss 0.907
# Epoch: 4 of 20
# 100% 2250/2250 [00:35<00:00, 63.88it/s, loss=0.817]
# Validation loss 0.806
# Epoch: 5 of 20
# 100% 2250/2250 [00:35<00:00, 63.96it/s, loss=0.726]
# Validation loss 0.764
# Epoch: 6 of 20
# 100% 2250/2250 [00:35<00:00, 63.56it/s, loss=0.648]
# Validation loss 0.846
# Epoch: 7 of 20
# 100% 2250/2250 [00:35<00:00, 64.15it/s, loss=0.588]
# Validation loss 0.711
# Epoch: 8 of 20
# 100% 2250/2250 [00:34<00:00, 64.36it/s, loss=0.532]
# Validation loss 0.677
# Epoch: 9 of 20
# 100% 2250/2250 [00:35<00:00, 64.08it/s, loss=0.478]
# Validation loss 0.681
# Epoch: 10 of 20
# 100% 2250/2250 [00:35<00:00, 63.69it/s, loss=0.434]
# Validation loss 0.700
# Epoch: 11 of 20
# 100% 2250/2250 [00:35<00:00, 63.68it/s, loss=0.393]
# Validation loss 0.715
# Epoch: 12 of 20
# 100% 2250/2250 [00:35<00:00, 63.72it/s, loss=0.358]
# Validation loss 0.689
# Epoch: 13 of 20
# 100% 2250/2250 [00:35<00:00, 63.92it/s, loss=0.326]
# Validation loss 0.735
# Epoch: 14 of 20
# 100% 2250/2250 [00:35<00:00, 64.25it/s, loss=0.298]
# Validation loss 0.858
# Epoch: 15 of 20
# 100% 2250/2250 [00:35<00:00, 63.74it/s, loss=0.274]
# Validation loss 0.808
# Epoch: 16 of 20
# 100% 2250/2250 [00:35<00:00, 63.90it/s, loss=0.251]
# Validation loss 0.762
# Epoch: 17 of 20
# 100% 2250/2250 [00:35<00:00, 64.18it/s, loss=0.229]
# Validation loss 0.864
# Epoch: 18 of 20
# 100% 2250/2250 [00:34<00:00, 64.55it/s, loss=0.219]
# Validation loss 0.870
# Epoch: 19 of 20
# 100% 2250/2250 [00:34<00:00, 65.09it/s, loss=0.204]
# Validation loss 0.939
# Epoch: 20 of 20
# 100% 2250/2250 [00:34<00:00, 64.82it/s, loss=0.190]
# Validation loss 0.901
# Finished training.
# Accuracy (or Dice for UNet) on the test set: 77.510 %
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=CnnVanilla --dataset=cifar10 --num-epochs=20 --data_aug
# Out:
# Data augmentation activated!!
# Files already downloaded and verified
# Files already downloaded and verified
# Training CnnVanilla on cifar10 for 20 epochs
# Epoch: 1 of 20
# 100% 2250/2250 [00:45<00:00, 49.10it/s, loss=1.653]
# Validation loss 1.355
# Epoch: 2 of 20
# 100% 2250/2250 [00:45<00:00, 49.25it/s, loss=1.269]
# Validation loss 1.092
# Epoch: 3 of 20
# 100% 2250/2250 [00:45<00:00, 49.12it/s, loss=1.044]
# Validation loss 0.997
# Epoch: 4 of 20
# 100% 2250/2250 [00:45<00:00, 49.00it/s, loss=0.920]
# Validation loss 0.857
# Epoch: 5 of 20
# 100% 2250/2250 [00:45<00:00, 49.30it/s, loss=0.841]
# Validation loss 0.800
# Epoch: 6 of 20
# 100% 2250/2250 [00:45<00:00, 49.44it/s, loss=0.775]
# Validation loss 0.819
# Epoch: 7 of 20
# 100% 2250/2250 [00:45<00:00, 49.34it/s, loss=0.730]
# Validation loss 0.715
# Epoch: 8 of 20
# 100% 2250/2250 [00:45<00:00, 49.27it/s, loss=0.683]
# Validation loss 0.737
# Epoch: 9 of 20
# 100% 2250/2250 [00:45<00:00, 49.35it/s, loss=0.652]
# Validation loss 0.631
# Epoch: 10 of 20
# 100% 2250/2250 [00:46<00:00, 48.53it/s, loss=0.620]
# Validation loss 0.644
# Epoch: 11 of 20
# 100% 2250/2250 [00:46<00:00, 48.07it/s, loss=0.591]
# Validation loss 0.622
# Epoch: 12 of 20
# 100% 2250/2250 [00:46<00:00, 48.03it/s, loss=0.573]
# Validation loss 0.625
# Epoch: 13 of 20
# 100% 2250/2250 [00:47<00:00, 47.60it/s, loss=0.548]
# Validation loss 0.587
# Epoch: 14 of 20
# 100% 2250/2250 [00:46<00:00, 48.37it/s, loss=0.528]
# Validation loss 0.596
# Epoch: 15 of 20
# 100% 2250/2250 [00:46<00:00, 48.69it/s, loss=0.509]
# Validation loss 0.537
# Epoch: 16 of 20
# 100% 2250/2250 [00:46<00:00, 48.88it/s, loss=0.489]
# Validation loss 0.559
# Epoch: 17 of 20
# 100% 2250/2250 [00:46<00:00, 48.89it/s, loss=0.476]
# Validation loss 0.540
# Epoch: 18 of 20
# 100% 2250/2250 [00:45<00:00, 49.13it/s, loss=0.451]
# Validation loss 0.521
# Epoch: 19 of 20
# 100% 2250/2250 [00:45<00:00, 48.97it/s, loss=0.434]
# Validation loss 0.539
# Epoch: 20 of 20
# 100% 2250/2250 [00:45<00:00, 49.18it/s, loss=0.425]
# Validation loss 0.509
# Finished training.
# Accuracy (or Dice for UNet) on the test set: 82.750 %
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=CnnVanilla --dataset=svhn --num-epochs=20
# Out:
# Data augmentation NOT activated!
# Using downloaded and verified file: ../data/train_32x32.mat
# Using downloaded and verified file: ../data/test_32x32.mat
# Training CnnVanilla on svhn for 20 epochs
# Epoch: 1 of 20
# 100% 3297/3297 [00:52<00:00, 62.46it/s, loss=0.874]
# Validation loss 0.443
# Epoch: 2 of 20
# 100% 3297/3297 [00:52<00:00, 62.53it/s, loss=0.402]
# Validation loss 0.370
# Epoch: 3 of 20
# 100% 3297/3297 [00:53<00:00, 61.73it/s, loss=0.335]
# Validation loss 0.321
# Epoch: 4 of 20
# 100% 3297/3297 [00:53<00:00, 61.13it/s, loss=0.295]
# Validation loss 0.307
# Epoch: 5 of 20
# 100% 3297/3297 [00:54<00:00, 60.89it/s, loss=0.260]
# Validation loss 0.279
# Epoch: 6 of 20
# 100% 3297/3297 [00:54<00:00, 60.93it/s, loss=0.235]
# Validation loss 0.279
# Epoch: 7 of 20
# 100% 3297/3297 [00:53<00:00, 61.38it/s, loss=0.212]
# Validation loss 0.285
# Epoch: 8 of 20
# 100% 3297/3297 [00:54<00:00, 60.88it/s, loss=0.194]
# Validation loss 0.263
# Epoch: 9 of 20
# 100% 3297/3297 [00:54<00:00, 61.03it/s, loss=0.178]
# Validation loss 0.294
# Epoch: 10 of 20
# 100% 3297/3297 [00:54<00:00, 61.04it/s, loss=0.166]
# Validation loss 0.302
# Epoch: 11 of 20
# 100% 3297/3297 [00:54<00:00, 61.01it/s, loss=0.153]
# Validation loss 0.297
# Epoch: 12 of 20
# 100% 3297/3297 [00:53<00:00, 61.38it/s, loss=0.142]
# Validation loss 0.313
# Epoch: 13 of 20
# 100% 3297/3297 [00:53<00:00, 61.10it/s, loss=0.136]
# Validation loss 0.318
# Epoch: 14 of 20
# 100% 3297/3297 [00:54<00:00, 60.78it/s, loss=0.122]
# Validation loss 0.431
# Epoch: 15 of 20
# 100% 3297/3297 [00:55<00:00, 59.37it/s, loss=0.116]
# Validation loss 0.355
# Epoch: 16 of 20
# 100% 3297/3297 [00:55<00:00, 59.40it/s, loss=0.110]
# Validation loss 0.343
# Epoch: 17 of 20
# 100% 3297/3297 [00:55<00:00, 59.75it/s, loss=0.104]
# Validation loss 0.372
# Epoch: 18 of 20
# 100% 3297/3297 [00:53<00:00, 61.44it/s, loss=0.099]
# Validation loss 0.352
# Epoch: 19 of 20
# 100% 3297/3297 [00:53<00:00, 61.63it/s, loss=0.096]
# Validation loss 0.360
# Epoch: 20 of 20
# 100% 3297/3297 [00:53<00:00, 61.74it/s, loss=0.089]
# Validation loss 0.406
# Finished training.
# Accuracy (or Dice for UNet) on the test set: 92.124 %
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=CnnVanilla --dataset=svhn --num-epochs=20 --data_aug
# Out:
# Data augmentation activated!!
# Using downloaded and verified file: ../data/train_32x32.mat
# Using downloaded and verified file: ../data/test_32x32.mat
# Training CnnVanilla on svhn for 20 epochs
# Epoch: 1 of 20
# 100% 3297/3297 [01:00<00:00, 54.54it/s, loss=1.241]
# Validation loss 0.849
# Epoch: 2 of 20
# 100% 3297/3297 [00:59<00:00, 55.01it/s, loss=0.716]
# Validation loss 0.635
# Epoch: 3 of 20
# 100% 3297/3297 [01:00<00:00, 54.67it/s, loss=0.605]
# Validation loss 0.543
# Epoch: 4 of 20
# 100% 3297/3297 [01:00<00:00, 54.39it/s, loss=0.540]
# Validation loss 0.532
# Epoch: 5 of 20
# 100% 3297/3297 [01:00<00:00, 54.36it/s, loss=0.499]
# Validation loss 0.485
# Epoch: 6 of 20
# 100% 3297/3297 [01:01<00:00, 54.02it/s, loss=0.467]
# Validation loss 0.453
# Epoch: 7 of 20
# 100% 3297/3297 [01:01<00:00, 53.93it/s, loss=0.446]
# Validation loss 0.433
# Epoch: 8 of 20
# 100% 3297/3297 [01:01<00:00, 53.74it/s, loss=0.425]
# Validation loss 0.432
# Epoch: 9 of 20
# 100% 3297/3297 [01:00<00:00, 54.11it/s, loss=0.409]
# Validation loss 0.426
# Epoch: 10 of 20
# 100% 3297/3297 [01:00<00:00, 54.32it/s, loss=0.392]
# Validation loss 0.382
# Epoch: 11 of 20
# 100% 3297/3297 [01:03<00:00, 52.20it/s, loss=0.383]
# Validation loss 0.378
# Epoch: 12 of 20
# 100% 3297/3297 [01:03<00:00, 51.94it/s, loss=0.373]
# Validation loss 0.369
# Epoch: 13 of 20
# 100% 3297/3297 [01:03<00:00, 52.04it/s, loss=0.363]
# Validation loss 0.378
# Epoch: 14 of 20
# 100% 3297/3297 [01:01<00:00, 53.48it/s, loss=0.347]
# Validation loss 0.347
# Epoch: 15 of 20
# 100% 3297/3297 [01:01<00:00, 53.36it/s, loss=0.338]
# Validation loss 0.362
# Epoch: 16 of 20
# 100% 3297/3297 [01:01<00:00, 53.28it/s, loss=0.332]
# Validation loss 0.341
# Epoch: 17 of 20
# 100% 3297/3297 [01:01<00:00, 53.45it/s, loss=0.316]
# Validation loss 0.322
# Epoch: 18 of 20
# 100% 3297/3297 [01:01<00:00, 53.22it/s, loss=0.308]
# Validation loss 0.335
# Epoch: 19 of 20
# 100% 3297/3297 [01:02<00:00, 53.14it/s, loss=0.300]
# Validation loss 0.328
# Epoch: 20 of 20
# 100% 3297/3297 [01:02<00:00, 53.10it/s, loss=0.287]
# Validation loss 0.327
# Finished training.
# Accuracy (or Dice for UNet) on the test set: 92.005 %
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=UNet --dataset=highway --num-epochs=1
# Out:
# Data augmentation NOT activated!
# Training UNet on highway for 1 epochs
# Epoch: 1 of 1
# 100% 62/62 [01:02<00:00,  1.01s/it, loss=1.227]
# Validation loss 1.080
# Finished training.
# Accuracy (or Dice for cp) on the test set: 13.467 %
# <Figure size 1000x1000 with 4 Axes>
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=UNet --dataset=highway --num-epochs=4 --continue_train
# Out:
# Data augmentation NOT activated!
# => loading checkpoint 'UNet_state'
# => loaded checkpoint 'UNet_state' (epoch 40)
# Training UNet on highway for 4 epochs
# Epoch: 41 of 44
# 100% 62/62 [01:02<00:00,  1.00s/it, loss=0.088]
# Validation loss 0.095
# Epoch: 42 of 44
# 100% 62/62 [01:02<00:00,  1.00s/it, loss=0.084]
# Validation loss 0.075
# Epoch: 43 of 44
# 100% 62/62 [01:02<00:00,  1.00s/it, loss=0.073]
# Validation loss 0.071
# Epoch: 44 of 44
# 100% 62/62 [01:02<00:00,  1.00s/it, loss=0.068]
# Validation loss 0.148
# Finished training.
# Accuracy (or Dice for cp) on the test set: 62.766 %
# <Figure size 1000x1000 with 4 Axes>
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=UNet --dataset=highway --num-epochs=10 --batch_size=1
# Out:
# Data augmentation NOT activated!!
# Training UNet on highway for 10 epochs
# Epoch: 1 of 10
# 100% 14/14 [00:24<00:00,  1.74s/it, loss=0.942]
# Validation loss 14.580
# Epoch: 2 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.793]
# Validation loss 1.599
# Epoch: 3 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.749]
# Validation loss 0.735
# Epoch: 4 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.717]
# Validation loss 0.723
# Epoch: 5 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.703]
# Validation loss 0.780
# Epoch: 6 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.681]
# Validation loss 0.723
# Epoch: 7 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.660]
# Validation loss 0.632
# Epoch: 8 of 10
# 100% 14/14 [00:07<00:00,  1.93it/s, loss=0.637]
# Validation loss 0.657
# Epoch: 9 of 10
# 100% 14/14 [00:07<00:00,  1.94it/s, loss=0.623]
# Validation loss 0.605
# Epoch: 10 of 10
# 100% 14/14 [00:07<00:00,  1.94it/s, loss=0.607]
# Validation loss 0.588
# Finished training.
# Accuracy (or Dice for cp) on the test set: 67.264 %
# <Figure size 1000x1000 with 4 Axes>
# <Figure size 1000x500 with 2 Axes>

# %%
# !python train.py --model=UNet --dataset=highway --predict
# Out:
# Data augmentation NOT activated!!
# Accuracy (or Dice for cp) on the test set: 67.987 %
# predicting the mask of a randomly selected image from test set
# <Figure size 1000x1000 with 4 Axes>

# %%
import os
os.listdir('../data/projetSession/groundTruth2')
# Out:
# ['1.png',
#  '2.png',
#  '3.png',
#  '4.png',
#  '5.png',
#  '6.png',
#  '8.png',
#  '9.png',
#  '7.png',
#  '16.png',
#  '19.png',
#  '11.png',
#  '18.png',
#  '14.png',
#  '17.png',
#  '15.png',
#  '13.png',
#  '10.png',
#  '12.png']

# %% [markdown]
# **For some unknown reasons matplotlib doesn't plot figures in google colab, so in ohter to visualize the plots we need to save figure as png first and then plot it using the below snippet of code**

# %%
from IPython.display import Image
Image('fig2.png')
