# %% [markdown]
# ### Mounting google drive

# %% [markdown]
# Since source files are stored into the drive, we need first to mount the drive in order to be able to import required files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Go to right directory

# %%
ls
# Out:
# sample_data/

# %%
cd drive/'My Drive'/tp3_ift725/prog/src
# Out:
# /content/drive/My Drive/tp3_ift725/prog/src

# %%
ls
# Out:
# CNNTrainTestManager.py          imput1.jpg              setup.py
# cross_validation_IFT725UNet.py  models/                 TP3.pdf
# DataManager.py                  predict_cnn.py          train.ipynb
# fig1.png                        predict_imput1.jpg      train.py
# fig2_1.png                      prediction/             UNet.pt
# fig2.png                        prediction.jpg          UNet_state
# HDF5Dataset.py                  ProjetHiver_DataSet.py  utils.py
# Highway_DataSet.py              __pycache__/
# images/                         pytorch_turorial.ipynb

# %%
# %matplotlib inline

# %%
# !python train.py --model=UNet --dataset=highway --predict --batch_size=1
# Out:
# Data augmentation NOT activated!!
# Accuracy (or Dice for cp) on the test set: 70.762 %
# predicting the mask of a randomly selected image from test set
# <Figure size 1000x1000 with 4 Axes>

# %%
# !python predict_cnn.py 12.jpg
# Out:
# model loaded.
# <Figure size 1000x1000 with 2 Axes>

# %% [markdown]
# **For some unknown reasons matplotlib doesn't plot figures in google colab, so in ohter to visualize the plots we need to save figure as png first and then plot it using the below snippet of code**

# %%
from IPython.display import Image
Image('fig2.png')
